# %%
#file upload command in Google Colab

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-da0f2469-cdb8-4810-91fe-5f27c0a9d8f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da0f2469-cdb8-4810-91fe-5f27c0a9d8f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#df.read_excel() command

import pandas as pd

df = pd.read_excel('Challenge 1.xlsx')

df
#print(df)
# Out:
#    Date of Sale    Division   Salesman   Product  Quantity  \
# 0    2022-01-08       Dhaka    Mushfiq    Laptop         2
# 1    2022-01-16  Chittagong     Raihan    Tablet         3
# 2    2022-01-17      Sylhet      Tamim    Laptop         4
# 3    2022-02-08      Sylhet      Tamim    Tablet         5
# 4    2022-02-14       Dhaka    Mushfiq    Mobile         2
# 5    2022-02-15  Chittagong  Subrina      Laptop         5
# 6    2022-03-04  Chittagong      Asif     Laptop         3
# 7    2022-03-09       Dhaka    Mushfiq        TV         4
# 8    2022-03-21  Chittagong      Asif     Tablet         2
# 9    2022-04-01       Dhaka    Mushfiq    Mobile         3
# 10   2022-04-04  Chittagong     Anika     Mobile         2
# 11   2022-04-08  Chittagong      Sakib    Tablet         3
# 12   2022-05-01       Dhaka    Mushfiq    Laptop         3
# 13   2022-05-09      Sylhet    Naseef         TV         1
# 14   2022-05-17       Dhaka    Mushfiq    Tablet         5
# ...
